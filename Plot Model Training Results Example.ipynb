# %%
from ptutils.core.utils import grab_results
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
result_list = grab_results(dbname='imagenet', 
                           collname='xentloss_resnet18', 
                           exp_id='exp0', 
                           port=27017)
val_results = result_list['results']['accs_top1']['val']
plt.plot(val_results)
plt.xlabel("Save Iteration")
plt.ylabel("Val Top1 Accuracy")
# Out:
# Text(0,0.5,'Val Top1 Accuracy')
